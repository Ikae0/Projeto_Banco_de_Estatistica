# %% [markdown]
# # **Este é o Quarto projeto do curso de Data Science na matéria de Estatística I.**
# # *Este curso é organizado pela Ada e patrocinado pelo Banco Santander.*
#
#
#
#
# <img src="https://www.meioemensagem.com.br/wp-content/uploads/2018/03/Santander_NovaMarca_575.png" alt="Imagem Logo Santader" width="400" height="200">
# <img src="https://ada-site-frontend.s3.sa-east-1.amazonaws.com/home/header-logo.svg" alt="Logo Ada" width="300" height="200">

# %% [markdown]
# **Dados**
#
# Crie uma conta no site kaggle.com, faça o download do dataset Body Fat Prediction, disponível gratuitamente [aqui](https://www.kaggle.com/datasets/fedesoriano/body-fat-prediction-dataset) e leia-o como um dataframe do pandas.
#
# Vamos utilizá-lo para que você possa demonstrar os seus conhecimentos em estatística 🙂

# %% [markdown]
# **Membros do Grupo:**
#
#
#
# *   Andressa
# *   Bruno
# *   Eduardo
# *   Karoline
# *   Vinicius Lima

# %% [markdown]
# **Objetivo Do Projeto**
#
#
# O projeto tem como objetivo aplicar conceitos fundamentais de estatística ao dataset "Body Fat Prediction" para praticar e demonstrar habilidades em análise de dados. As áreas focais incluem estatística descritiva, análise de correlação, estudo de distribuições de probabilidade, realização de testes de hipóteses e técnicas de amostragem estatística. Através dessas atividades,  buscamos compreender melhor as características e relações presentes nos dados, modelar fenômenos estatísticos e tomar decisões baseadas em evidências, preparando-se para desafios analíticos em contextos profissionais e acadêmicos.

# %% [markdown]
# ## Importando o Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
 #import database
bf_dataset = pd.read_csv(r'/content/bodyfat.csv')
bf_dataset
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# ...

# %% [markdown]
# ## Questão 1
#
# Utilizando seus conhecimentos em Estatística Descritiva, forneça algumas análises sobre as colunas que julgar mais relevantes do dataset.
#
# a) Para as colunas que você escolher, mostre-me as métricas de posição e de dispersão que julgar interessantes.

# %%
#First, let's just lool at our dataset
bf_dataset.head()
# Out:
#    Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 0  37.3   21.9    32.0     27.4   17.1
# 1  37.3   23.4    30.5     28.9   18.2
# 2  38.9   24.0    28.8     25.2   16.6
# 3  37.3   22.8    32.4     29.4   18.2
# 4  42.2   24.0    32.2     27.7   17.7

# %%
#Having a basic look on our dataset characteristics
bf_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Density  252 non-null    float64
#  1   BodyFat  252 non-null    float64
#  2   Age      252 non-null    int64
#  3   Weight   252 non-null    float64
#  4   Height   252 non-null    float64
#  5   Neck     252 non-null    float64
#  6   Chest    252 non-null    float64
#  7   Abdomen  252 non-null    float64
#  8   Hip      252 non-null    float64
#  9   Thigh    252 non-null    float64
#  10  Knee     252 non-null    float64
#  11  Ankle    252 non-null    float64
#  12  Biceps   252 non-null    float64
#  13  Forearm  252 non-null    float64
#  14  Wrist    252 non-null    float64
# dtypes: float64(14), int64(1)
# memory usage: 29.7 KB

# %%
#For making the information showed more explanatory, it's appropriate to convert Weight and Height to kg and cm respectively
bf_dataset['Weight'] = (bf_dataset['Weight']*0.4535).round(2)
bf_dataset['Height'] = (bf_dataset['Height']*2.54).round(2)

#--WARNING - execute this block of code individually will cause the calculation to be repeated and by consequence change the values

bf_dataset
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23   69.95  172.08  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22   78.57  183.52  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22   69.84  168.28  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26   83.78  183.52  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24   83.56  180.98  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70   60.88  170.18  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72   91.15  177.16  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72   84.69  167.64  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72   86.51  179.07  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74   94.10  177.80  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# ...

# %%
#Now that we have the most suitable units, we can have a look on some main tendency and dispersion measures with describe
bf_dataset.describe()
# Out:
#           Density     BodyFat         Age      Weight      Height        Neck  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean     1.055574   19.150794   44.884921   81.142421  178.178016   37.992063
# std      0.019031    8.368740   12.602040   13.327818    9.303911    2.430913
# min      0.995000    0.000000   22.000000   53.740000   74.930000   31.100000
# 25%      1.041400   12.475000   35.750000   72.107500  173.360000   36.400000
# 50%      1.054900   19.200000   43.000000   80.045000  177.800000   38.000000
# 75%      1.070400   25.300000   54.000000   89.340000  183.520000   39.425000
# max      1.108900   47.500000   81.000000  164.690000  197.480000   51.200000
#
#             Chest     Abdomen         Hip       Thigh        Knee       Ankle  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   100.824206   92.555952   99.904762   59.405952   38.590476   23.102381
# ...

# %%
#We can check by this analysis that somehow there's a person 74 centimeters high, which is an absurd. Even if this measurement is right, the conditions that take someone to have these features
#would show a clinical situation of nanism that is not intended to be analysed here. For this reason, it's better to discard this outlier
bf_dataset.drop(bf_dataset[bf_dataset['Height']<=100].index,inplace=True)

# %% [markdown]
# b) Faça um pré-julgamento a respeito das colunas deste dataset tentando encontrar um par de colunas que, pela lógica, deve ser altamente correlacionado e outro par de colunas que, pela lógica, deve ser fracamente correlacionado. Depois utilize as métricas de correlação que você aprendeu para pôr à prova essas suas opiniões, isto é, para descobrir se matemática confirma suas crenças
# iniciais ou não.

# %%
#It's expected that a person with higher BodyFat will probably have a wider abdomen
# Let's try to see this correlation in a graph
plt.figure(figsize=(12, 7))
sns.scatterplot(x=bf_dataset['BodyFat'], y=bf_dataset['Abdomen'], color = 'lightblue').set_title('BodyFat x Abdomen Circunference')
# Out:
# Text(0.5, 1.0, 'BodyFat x Abdomen Circunference')

# %%
#As we can see, it seens to exist a significant correlation between these columns
#But to confirm that, we need to apply a mathematical approuch

pearson = bf_dataset['BodyFat'].corr(bf_dataset['Abdomen'],method='pearson')
spearman = bf_dataset['BodyFat'].corr(bf_dataset['Abdomen'],method='spearman')
kendall = bf_dataset['BodyFat'].corr(bf_dataset['Abdomen'],method='kendall')


print(
'Pearson Correlation: ',pearson,'\n'

'Spearman Correlation: ',spearman,'\n'

'Kendall Correlation: ',kendall,sep='\n'
)
# Out:
# Pearson Correlation:
# 0.8125931561306915
#
# Spearman Correlation:
# 0.8147415880242399
#
# Kendall Correlation:
# 0.6196944528129723

# %%
#In the other hand, the relation between Height and BodyFat is probably inexistent or way lower than the previos one. Let's see the graph and correlation scores
pearson = bf_dataset['Height'].corr(bf_dataset['BodyFat'],method='pearson')
spearman = bf_dataset['Height'].corr(bf_dataset['BodyFat'],method='spearman')
kendall = bf_dataset['Height'].corr(bf_dataset['BodyFat'],method='kendall')

plt.figure(figsize=(12, 7))
sns.scatterplot(x = bf_dataset['BodyFat'], y=bf_dataset['Height'],color = 'lightblue').set_title('BodyFat x Height')

print(
'Pearson Correlation: ',pearson,'\n'

'Spearman Correlation: ',spearman,'\n'

'Kendall Correlation: ',kendall,sep='\n'
)
# Out:
# Pearson Correlation:
# -0.023388816766849875
#
# Spearman Correlation:
# 0.0027586506206872708
#
# Kendall Correlation:
# -0.00019402783145850094

# %% [markdown]
# c) Escolha pelo menos uma coluna que siga a distribuição normal, plote um scatterplot e explique como você fez para concluir que esta coluna segue uma distribuição normal.

# %%
#Plotting the Height colunm distribution
plt.figure(figsize=(12, 7))
sns.histplot(bf_dataset['Height'], color='lightblue').set_title('Height Histogram')
plt.grid(axis='y', linestyle='--')
plt.xticks(rotation=45)
plt.show()

# %%
#According to the normal distribution definition, if we get the mean of random samples collected from our data, we should see something that aproximately close to a bell curve, so let's try to see that

#get samples of X values randomly from this distribution and plot the mean of each sample
samples_list = [ np.random.choice(bf_dataset['Height'],5).mean() for _ in range(200)]
samples_series = pd.Series(samples_list)

plt.figure(figsize=(12, 7))
sns.histplot(samples_series,bins=10, color='lightblue').set_title('Height Sample Means')
plt.grid(axis='y', linestyle='--')
plt.xticks(rotation=45)
plt.show()

# %%
#We can see that it seens Normal, but in order to be sure of that we need to perform the Shapiro-Wilk test for evaluating if the data follows a normal distribution
ShapiroResult, pvalue = stats.shapiro(bf_dataset['Height'])

print(f'The Shapiro result is: {ShapiroResult:.3f}',f'The p-value is: {pvalue:.3f}',sep='\n')
# Out:
# The Shapiro result is: 0.992
# The p-value is: 0.232

# %%
# By the p-value > 0.05, we can consider this as a Normal distribution

# %% [markdown]
# ## Questão 2
#
# Considerando o mesmo dataset e tomando-o como espaço amostral, responda _(fique à vontade para usar o Python para facilitar a sua vida aqui)_:
#
# a) Qual é a probabilidade de uma pessoa selecionada ao acaso ter uma idade (coluna Age) superior a 40 anos?
#
# b) Qual é a probabilidade de uma pessoa selecionada ao acaso ter um percentual de gordura corporal (coluna BodyFat) superior a 20%?
#
# c) Qual é a probabilidade de uma pessoa selecionada ao acaso ter um percentual de gordura corporal (coluna BodyFat) superior a 20% e ao mesmo tempo ter uma idade (coluna Age) superior a 40 anos?
#
#  d) Qual é a probabilidade de uma pessoa selecionada ao acaso ter um percentual de gordura corporal (coluna BodyFat) superior a 20% se eu já souber de antemão que esta pessoa tem uma idade superior a 40 anos?

# %%
#A: Montamos Uma classe com os valores da coluna BodyFat
a = bf_dataset[ bf_dataset['BodyFat'] >20]

#dividimos o tamanho dessa nova classe  pelo tamanho da das linhas do bf_dataset
porcentagem1 = (len(a) / len(bf_dataset)) * 100
print(f"A porcentagem de pessoas com gordura corporal acima de 20% é: {porcentagem1:.2f}%")

#B:Agora para os valores maiores que 20
b = bf_dataset[ bf_dataset['BodyFat'] <20]
porcentagem2 = (len(b) / len(bf_dataset)) * 100
print(f"A porcentagem de pessoas com gordura corporal abaixo de 20% é: {porcentagem2:.2f}%")

#C: Agora agrupamos todas as pessoas com gordura corporal acima de 20 que a idade acima de 40
c = bf_dataset[ (bf_dataset['BodyFat'] >20) & (bf_dataset['Age'] > 40)]
#dividimos pelo numero total de colunas
porcentagem1 = (len(c) / len(bf_dataset)) * 100
print(f"A porcentagem de pessoas com gordura corporal acima de 20% que tem acima de 40 anos é : {porcentagem1:.2f}%")

#D:agrupamos todas as pessoas com gordura corporal acima de 20 que a idade acima de 40
d = bf_dataset[ (bf_dataset['BodyFat'] >20) & (bf_dataset['Age'] > 40)]
# dividindo pelo numero de pessoas acima de 40 anos
age=bf_dataset[ bf_dataset['Age'] >40]
porcentagem1 = (len(d) / len(age)) * 100
print(f"Entre as pessoas com 40 anos a porcentagem de pessoas com gordura corporal acima de 20% é: {porcentagem1:.2f}%")
# Out:
# A porcentagem de pessoas com gordura corporal acima de 20% é: 47.62%
# A porcentagem de pessoas com gordura corporal abaixo de 20% é: 52.38%
# A porcentagem de pessoas com gordura corporal acima de 20% que tem acima de 40 anos é : 34.92%
# Entre as pessoas com 40 anos a porcentagem de pessoas com gordura corporal acima de 20% é: 55.00%

# %% [markdown]
# ## Questão 3
#
# Durante o módulo, nós definimos algumas distribuições de probabilidade, cada uma
# com uma função de probabilidade.

# %% [markdown]
# **a) Escolha uma delas que não seja uma distribuição normal, e explique (talvez com algum exemplo) que tipos de evento esta distribuição descreve.**
#
# R.- A distribuição de Poisson descreve a probabilidade de um número discreto de eventos ocorrerem no mesmo intervalo de tempo em um determinado espaço. Todos os eventos ocorrem de forma independente e a sua taxa média também é conhecida.
#
# Considere, por exemplo, que estamos interessados em analisar o número de mortes causadas por coices de cavalo em uma fazenda durante um ano. A ocorrência de uma morte por coice de cavalo não afeta a probabilidade de ocorrer outra morte por coice de cavalo no mesmo período de tempo. Isso pode ser uma suposição razoável se as mortes forem causadas por diferentes circunstâncias (diferentes cavalos e pessoas envolvidas, por exemplo). Além disso, suponha que a taxa média de mortes por coice de cavalo na fazenda seja de 0,1 por ano. Portanto, usando a distribuição de Poisson podemos calcular a probabilidade de diferentes pessoas morrerem por coice de cavalo na fazenda durante 10 anos, por exemplo.

# %% [markdown]
# **b) Explique a utilidade prática das funções de probabilidade. Quero dizer: para quê elas servem? De que modo elas nos ajudam?**
#
# R.- As funções de probabilidade podem ser utilizadas para modelar sistemas complexos e/ou estocásticos, para identificar desvios no padrão de qualidade em algum processo onde é definido um target, fazer testes de hipóteses para identificar características estatisticamente significativas para determinado grupo de amostras, fazer previsões e estimativas de eventos futuros  com o intuito de trabalhar as incertezas na tomada de decisões.

# %% [markdown]
# c) Escolha uma das colunas do nosso dataset que sejam contínuas e que sigam uma distribuição normal, e calcule a probabilidade de uma pessoa escolhida ao
# acaso ter um valor > x para esta coluna (por exemplo, probabilidade de neck ser maior que 45). Mas, atenção: faça isso usando z-scores, através da função _st.norm.cdf_, do pacote Python scipy.stats.

# %%
import seaborn as sns
import scipy.stats as stats

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Após efetuar os testes de normalidade para todas as colunas, escolhemos a coluna Forearm como distribuição de interesse.

# %%
#Plotting the Forearm colunm distribution

plt.figure(figsize = (12, 7))
sns.histplot(bf_dataset['Forearm'], color = 'lightblue').set_title('Forearm Histogram')
plt.grid(axis = 'y', linestyle = '--')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# Vamos fazer um código para verificar se os dados na coluna **Forearm** do dataframe **bf_dataset** seguem uma distribuição normal. Utilizamos para tal o teste de normalidade de Shapiro-Wilk. As hipóteses são: se o p-valor for maior do que o nível de significância escolhido, podemos assumir que os dados seguem uma distribuição normal. Caso contrário, podemos concluir que os dados não seguem uma distribuição normal.
# Vamos escolher um valor de nível de significância como sendo 0.05 por ser o mais comum. Este valor corresponde a uma probabilidade de 5% de cometer um erro do tipo I. Ou seja, de rejeitar a hipótese nula quando ela é verdadeira.

# %%
# teste de normalidade da distribuição

from scipy.stats import zscore, norm, shapiro

stat, p_valor = shapiro(bf_dataset['Forearm'])
alpha = 0.05

print(f'O valor estatístico do teste de normalidade de Shapiro-Wilk é: {stat:.4f}')
if p_valor > alpha:
  print('A distribuição não é normal')
else:
  print('A distribuição é normal')
# Out:
# O valor estatístico do teste de normalidade de Shapiro-Wilk é: 0.9888
# A distribuição é normal

# %% [markdown]
# Para a coluna de interesse vamos utilizar algumas funções da biblioteca scipy.stats para calcular o z-score, que é uma medida de quantos desvios padrão um certo valor está acima ou abaixo da média. O z-score é calculado usando a equação:
#
# $Z = \frac{x - \mu}{\sigma}$\,
#
# sendo $\mu$ a média e $\sigma$ o desvio padrão.
#
# Escolhemos o valor $x = 29$ da distribuição para calcular a probabilidade de um valor da coluna **Forearm** ser maior do que esse valor.
#
# Para calcular essa probabilidade utilizamos a seguinte equação para a distribuição normal:
#
# $P(X > x) = 1 - P(X \leq x)$\,
#
# onde $P(X \leq x)$ é calculada usando a distribuição acumulada normal para $X$.

# %%
# análise dos dados da coluna de interesse (Forearm)

bf_dataset['Z_Score'] = zscore(bf_dataset['Forearm'])

x = 29

probabilidade = 1 - norm.cdf(x, loc = bf_dataset['Forearm'].mean(), scale = bf_dataset['Forearm'].std())

print(f'A probabilidade de Forearm ser maior que {x:.1f} é de {probabilidade*100:.1f}%')
# Out:
# A probabilidade de Forearm ser maior que 29.0 é de 43.4%

# %% [markdown]
# ## Questão 4
#
# Escolha uma coluna de valores contínuos A que seja do seu interesse. Depois disso, filtre os registros da sua tabela usando uma segunda coluna B. E, por fim, valendo-se dos seus conhecimentos sobre p-valor, diga se a média de A antes da filtragem é de fato significativamente diferente da média dos valores de A pós filtragem, com um nível de confiança de 95%.
#
# > Por exemplo: a coluna BodyFat tem uma determinada média geral. Se filtrarmos o nosso dataset para que ele inclua apenas registros com circunferência abdominal (coluna Abdomen) >= 85, certamente a média da coluna BodyFat mudará. Mas, podemos afirmar, com 95% de confiança estatística, que essa média pós-filtragem é, de fato, diferente da média original?

# %% [markdown]
# ---
#
#
#  A coluna escolhida  é "Weight" (A) será filtrada a partir da coluna "Knee" (B) determinado pelos valores <=38.
#
# * H0 - hipótese nula: A média de A ("Weight") se mantém igual mesmo após a filtragem.
# * H1 - hipótese alternativa: A média de A ("Weight") é diferente após a filtragem.

# %%
# Média original da coluna "Weight"
media_peso = bf_dataset['Weight'].mean()
print('Média da coluna A:', media_peso)

std_peso = bf_dataset['Weight'].std()
print("O desvio padrão de A antes do filtro:", std_peso, "\n")

# Filtragem
mascara = (bf_dataset['Knee'] <= 38) # Seleciona apenas valores de peso em que o joelho é <=38

dataset_filtrado = bf_dataset.loc[mascara,['Knee', 'Weight']] # Filtra os valores do peso que estão de acordo com a mascara

# Média da coluna "Weight" após filtragem
media_peso_filtrado = dataset_filtrado['Weight'].mean()
print("Média da coluna A após filtro da coluna B:", media_peso_filtrado)

std_peso_filtrado = dataset_filtrado['Weight'].std()
print("O desvio padrão de A após o filtro:", std_peso_filtrado)
# Out:
# Média da coluna A: 178.92440476190475
# O desvio padrão de A antes do filtro: 29.38915988536906
#
# Média da coluna A após filtro da coluna B: 157.329
# O desvio padrão de A após o filtro: 18.049017405192153

# %%
from scipy.stats import ttest_ind

# Realizando teste t de duas amostras
t_stat, p_valor = stats.ttest_ind(bf_dataset['Weight'], dataset_filtrado['Weight'])

# Verificando se o valor p é menor que o nível de significância
nivel_confianca = 0.95
alpha = 0.05

if p_valor < (alpha):
    print("Rejeitamos a hipótese nula. A média após o filtro é significativamente diferente da média original.")
else:
    print("Não rejeitamos a hipótese nula. Não há evidência suficiente para afirmar que as médias são diferentes.")

print("Valor t : ", t_stat)
print("Valor p : ", p_valor)
# Out:
# Rejeitamos a hipótese nula. A média após o filtro é significativamente diferente da média original.
# Valor t :  6.849913712809715
# Valor p :  3.3352909262963326e-11

# %%
# Plotando histograma de distribuição
plt.figure(figsize=(8,4))
plt.hist(x=bf_dataset['Weight'], bins=20, color='skyblue', alpha=0.7, rwidth=0.85, density=True, label='Dados coluna A')
plt.hist(x=dataset_filtrado['Weight'], bins=20, color='salmon', alpha=0.5, rwidth=0.85, density=True, label='Dados coluna A após filtro')
plt.axvline(x=bf_dataset['Weight'].mean(), color='blue', linestyle='dashed', linewidth=1, label='Média')
plt.axvline(x=dataset_filtrado['Weight'].mean(), color='red', linestyle='dashed', linewidth=1, label='Média após filtro')
plt.xlabel('Weight (A)')
plt.legend()
plt.title('Distribuições de Peso Antes e Após o Filtro')
plt.show()

# %% [markdown]
# ## Questão 5
#
# Pesquisas eleitorais envolvem, quase sempre, um imenso problema estatístico: a menos que você esteja interessado nas eleições municipais de uma cidade com 5 mil
# habitantes, você nunca terá o tempo e o orçamento necessários para entrevistar 100% dos potenciais eleitores. Imagine só, como poderíamos entrevistar mais de 100 milhões
# de pessoas para tentar prever com exatidão o resultado das eleições presidenciais do Brasil?
#
# Utilizando os seus conhecimentos sobre amostragem estatística, descreva como você faria para selecionar, por exemplo, 20 mil pessoas para serem entrevistadas, com o objetivo de produzir uma amostra que seja minimamente
# suficiente para predizer as intenções de voto de um grupo tão maior de pessoas quanto no caso das eleições presidenciais brasileiras. Explique, também, por que você tomou essa decisão e diga qual é o nome do tipo de amostragem estatística que você utilizou.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Vamos assumir uma população eleitoral de 100.000 para simplificar a simulação
populacao = {
    'Norte': 15000,
    'Nordeste': 25000,
    'Sudeste': 30000,
    'Sul': 20000,
    'Centro-Oeste': 10000
}


df_populacao = pd.DataFrame(list(populacao.items()), columns=['Região', 'População'])


df_populacao['Proporção'] = df_populacao['População'] / df_populacao['População'].sum()


tamanho_amostra = 20000


df_populacao['Tamanho Amostra'] = (df_populacao['Proporção'] * tamanho_amostra).round().astype(int)




df_populacao = pd.DataFrame(list(populacao.items()), columns=['Região', 'População'])
df_populacao['Proporção'] = df_populacao['População'] / df_populacao['População'].sum()
tamanho_amostra = 20000
df_populacao['Tamanho Amostra'] = (df_populacao['Proporção'] * tamanho_amostra).round().astype(int)

# Criando um gráfico para visualizar tanto a população total quanto o tamanho da amostra por região
plt.figure(figsize=(12, 7))

# Gráfico de barras para a população total
bar1 = plt.bar(df_populacao['Região'], df_populacao['População'], color='lightblue', label='População Total', width=0.4, align='center')

# Gráfico de barras para o tamanho da amostra
bar2 = plt.bar(df_populacao['Região'], df_populacao['Tamanho Amostra'], color='orange', label='Tamanho da Amostra', width=0.4, align='edge')

plt.xlabel('Região')
plt.ylabel('Número de Pessoas')
plt.title('Comparação entre População Total e Tamanho da Amostra por Região')
plt.legend()
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--')
print(df_populacao)
plt.show()
# Out:
#          Região  População  Proporção  Tamanho Amostra
# 0         Norte      15000       0.15             3000
# 1      Nordeste      25000       0.25             5000
# 2       Sudeste      30000       0.30             6000
# 3           Sul      20000       0.20             4000
# 4  Centro-Oeste      10000       0.10             2000

# %% [markdown]
# Nossa simulação dividiu uma hipotética população eleitoral em cinco regiões, distribuindo proporcionalmente uma amostra de 20.000 pessoas entre elas para assegurar representatividade geográfica. Isso prepara o terreno para uma seleção aleatória de indivíduos por região, visando análises de intenções de voto. A estratégia demonstra a eficácia da amostragem estratificada em pesquisas eleitorais, permitindo inferências estatísticas precisas de uma amostra menor em comparação à população geral.

# %% [markdown]
# **Conclusão**

# %% [markdown]
# Utilizar a amostragem estratificada permite a criação de uma amostra representativa de uma população vasta e diversa, como a dos eleitores brasileiros. Ao considerar as particularidades de diferentes grupos dentro da população, essa abordagem aumenta a precisão das estimativas de intenção de voto e fornece insights valiosos para prever o resultado de eleições com um alto grau de confiança. Este método, portanto, é essencial para pesquisas eleitorais, permitindo a análise eficiente e eficaz das tendências de voto em um contexto de recursos limitados.
